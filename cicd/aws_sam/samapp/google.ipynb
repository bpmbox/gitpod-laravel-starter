# %%
# !pip install aws-sam-cli
# !sam local start-api
# Out:
# Collecting aws-sam-cli
#   Downloading aws_sam_cli-1.40.1-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 36.5 MB/s eta 0:00:00a 0:00:01
# Collecting aws-sam-translator==1.42.0
#   Downloading aws_sam_translator-1.42.0-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 KB 39.5 MB/s eta 0:00:00
# Collecting dateparser~=1.0
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 KB 49.5 MB/s eta 0:00:00
# Collecting docker~=4.2.0
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 27.8 MB/s eta 0:00:00
# Collecting jmespath~=0.10.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting tzlocal==3.0
#   Downloading tzlocal-3.0-py3-none-any.whl (16 kB)
# Collecting click~=7.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 KB 18.2 MB/s eta 0:00:00
# Collecting cookiecutter~=1.7.2
#   Downloading cookiecutter-1.7.3-py2.py3-none-any.whl (34 kB)
# Collecting watchdog==2.1.2
#   Downloading watchdog-2.1.2-py3-none-manylinux2014_x86_64.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 KB 17.6 MB/s eta 0:00:00
# Collecting tomlkit==0.7.2
#   Downloading tomlkit-0.7.2-py2.py3-none-any.whl (32 kB)
# Collecting boto3==1.*,>=1.18.32
#   Downloading boto3-1.21.17-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 22.1 MB/s eta 0:00:00
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 KB 13.9 MB/s eta 0:00:00
# Collecting chevron~=0.12
#   Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Collecting MarkupSafe==2.0.1
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting Flask~=1.1.2
#   Downloading Flask-1.1.4-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 KB 23.1 MB/s eta 0:00:00
# Collecting typing-extensions==3.10.0.0
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting serverlessrepo==0.1.10
#   Downloading serverlessrepo-0.1.10-py2.py3-none-any.whl (23 kB)
# Collecting regex==2021.9.30
#   Downloading regex-2021.9.30-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.1/763.1 KB 46.9 MB/s eta 0:00:00
# Collecting PyYAML~=5.3
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 47.6 MB/s eta 0:00:00
# Collecting aws-lambda-builders==1.13.0
#   Downloading aws_lambda_builders-1.13.0-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 KB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.11 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (1.16.0)
# Requirement already satisfied: wheel in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (0.37.1)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (60.9.3)
# Collecting jsonschema~=3.2
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 14.1 MB/s eta 0:00:00
# Collecting botocore<1.25.0,>=1.24.17
#   Downloading botocore-1.24.17-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 78.9 MB/s eta 0:00:00:00:0100:01
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (2021.10.8)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 KB 36.6 MB/s eta 0:00:00
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 14.9 MB/s eta 0:00:00
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-manylinux1_x86_64.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 KB 17.5 MB/s eta 0:00:00
# Collecting python-slugify>=4.0.0
#   Downloading python_slugify-6.1.1-py2.py3-none-any.whl (9.1 kB)
# Collecting poyo>=0.5.0
#   Downloading poyo-0.5.0-py2.py3-none-any.whl (10 kB)
# Collecting jinja2-time>=0.2.0
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Collecting binaryornot>=0.4.4
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (3.0.3)
# Requirement already satisfied: python-dateutil in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from dateparser~=1.0->aws-sam-cli) (2.8.2)
# Collecting pytz
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 KB 61.7 MB/s eta 0:00:00
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 11.9 MB/s eta 0:00:00
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2<4.0.0,>=2.7
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 KB 32.3 MB/s eta 0:00:00
# Collecting Werkzeug<2.0,>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.6/298.6 KB 49.4 MB/s eta 0:00:00
# Collecting arrow
#   Downloading arrow-1.2.2-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 KB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from jsonschema~=3.2->aws-sam-translator==1.42.0->aws-sam-cli) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from jsonschema~=3.2->aws-sam-translator==1.42.0->aws-sam-cli) (0.18.1)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 KB 18.4 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, text-unidecode, regex, pytz, chevron, Werkzeug, websocket-client, watchdog, tomlkit, PyYAML, python-slugify, poyo, MarkupSafe, jsonschema, jmespath, itsdangerous, idna, click, chardet, backports.zoneinfo, aws-lambda-builders, tzlocal, requests, Jinja2, botocore, binaryornot, arrow, s3transfer, jinja2-time, Flask, docker, dateparser, cookiecutter, boto3, serverlessrepo, aws-sam-translator, aws-sam-cli
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.1.1
#     Uninstalling typing_extensions-4.1.1:
#       Successfully uninstalled typing_extensions-4.1.1
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.0
#     Uninstalling MarkupSafe-2.1.0:
#       Successfully uninstalled MarkupSafe-2.1.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.4.0
#     Uninstalling jsonschema-4.4.0:
#       Successfully uninstalled jsonschema-4.4.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.0.3
#     Uninstalling Jinja2-3.0.3:
#       Successfully uninstalled Jinja2-3.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# black 22.1.0 requires click>=8.0.0, but you have click 7.1.2 which is incompatible.
# Successfully installed Flask-1.1.4 Jinja2-2.11.3 MarkupSafe-2.0.1 PyYAML-5.4.1 Werkzeug-1.0.1 arrow-1.2.2 aws-lambda-builders-1.13.0 aws-sam-cli-1.40.1 aws-sam-translator-1.42.0 backports.zoneinfo-0.2.1 binaryornot-0.4.4 boto3-1.21.17 botocore-1.24.17 chardet-4.0.0 chevron-0.14.0 click-7.1.2 cookiecutter-1.7.3 dateparser-1.1.0 docker-4.2.2 idna-2.10 itsdangerous-1.1.0 jinja2-time-0.2.0 jmespath-0.10.0 jsonschema-3.2.0 poyo-0.5.0 python-slugify-6.1.1 pytz-2021.3 regex-2021.9.30 requests-2.25.1 s3transfer-0.5.2 serverlessrepo-0.1.10 text-unidecode-1.3 tomlkit-0.7.2 typing-extensions-3.10.0.0 tzlocal-3.0 watchdog-2.1.2 websocket-client-1.3.1
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python3 -m pip install --upgrade pip' command.
# Error: Template file not found at /workspace/gitpod-laravel-starter/cicd/aws_sam/samapp/template.yml

# %%
! settings

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="PASSWORD")

# %%
    1  ! pyenv shell 3.8.12
    2  ! sam init --runtime=python3.8
    3  ! pip install aws-sam-cli
    4  ! sam
    5  ! kdir samapp
    6  ! mkdir samapp
    7  ! cd samapp/
    8  ! python -m venv venv
    9  ! . ./venv/bin/activate
   10  ! sam init --runtime python3.7
   11  ! cd sam-app/
   12  ! sam build
   13  ! deactivate
   14  ! sam build
   15  ! sam
   16  ! sam build
   17  ! cd ..
   18  ! rm -rf ./sam-app/
   19  ! sam init --runtime python3.8
   20  ! cd ./sam-app/
   21  ! sam build
   22 !  sam local start-api
   23 !  sam deploy --guided
   24 !  aws
   25 !  aws configure
   26 !  sam deploy --guided
   27 !  ls -al
   28 !  history > build.txt
