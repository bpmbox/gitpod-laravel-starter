# %%
# !pip install aws-sam-cli
# !sam local start-api
# Out:
# Requirement already satisfied: aws-sam-cli in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (1.40.1)
# Requirement already satisfied: click~=7.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (7.1.2)
# Requirement already satisfied: chevron~=0.12 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (0.14.0)
# Requirement already satisfied: serverlessrepo==0.1.10 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (0.1.10)
# Requirement already satisfied: PyYAML~=5.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (5.4.1)
# Requirement already satisfied: cookiecutter~=1.7.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.7.3)
# Requirement already satisfied: dateparser~=1.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.1.0)
# Requirement already satisfied: tzlocal==3.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (3.0)
# Requirement already satisfied: typing-extensions==3.10.0.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (3.10.0.0)
# Requirement already satisfied: tomlkit==0.7.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (0.7.2)
# Requirement already satisfied: Flask~=1.1.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.1.4)
# Requirement already satisfied: watchdog==2.1.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (2.1.2)
# Requirement already satisfied: jmespath~=0.10.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (0.10.0)
# Requirement already satisfied: boto3==1.*,>=1.18.32 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.21.17)
# Requirement already satisfied: aws-sam-translator==1.42.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.42.0)
# Requirement already satisfied: regex==2021.9.30 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (2021.9.30)
# Requirement already satisfied: requests==2.25.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (2.25.1)
# Requirement already satisfied: MarkupSafe==2.0.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (2.0.1)
# Requirement already satisfied: aws-lambda-builders==1.13.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (1.13.0)
# Requirement already satisfied: docker~=4.2.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-cli) (4.2.2)
# Requirement already satisfied: wheel in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (0.37.1)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (60.9.3)
# Requirement already satisfied: six~=1.11 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-lambda-builders==1.13.0->aws-sam-cli) (1.16.0)
# Requirement already satisfied: jsonschema~=3.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from aws-sam-translator==1.42.0->aws-sam-cli) (3.2.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from boto3==1.*,>=1.18.32->aws-sam-cli) (1.24.17)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from boto3==1.*,>=1.18.32->aws-sam-cli) (0.5.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests==2.25.1->aws-sam-cli) (2.10)
# Requirement already satisfied: backports.zoneinfo in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tzlocal==3.0->aws-sam-cli) (0.2.1)
# Requirement already satisfied: poyo>=0.5.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (0.5.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (2.11.3)
# Requirement already satisfied: python-slugify>=4.0.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (6.1.1)
# Requirement already satisfied: binaryornot>=0.4.4 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (0.4.4)
# Requirement already satisfied: jinja2-time>=0.2.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from cookiecutter~=1.7.2->aws-sam-cli) (0.2.0)
# Requirement already satisfied: pytz in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from dateparser~=1.0->aws-sam-cli) (2021.3)
# Requirement already satisfied: python-dateutil in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from dateparser~=1.0->aws-sam-cli) (2.8.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from docker~=4.2.0->aws-sam-cli) (1.3.1)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from Flask~=1.1.2->aws-sam-cli) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from Flask~=1.1.2->aws-sam-cli) (1.1.0)
# Requirement already satisfied: arrow in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from jinja2-time>=0.2.0->cookiecutter~=1.7.2->aws-sam-cli) (1.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from jsonschema~=3.2->aws-sam-translator==1.42.0->aws-sam-cli) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from jsonschema~=3.2->aws-sam-translator==1.42.0->aws-sam-cli) (0.18.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from python-slugify>=4.0.0->cookiecutter~=1.7.2->aws-sam-cli) (1.3)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/gitpod/.pyenv/versions/3.8.12/bin/python3 -m pip install --upgrade pip' command.
# Mounting HelloWorldFunction at http://127.0.0.1:3000/hello [GET]
# You can now browse to the above endpoints to invoke your functions. You do not need to restart/reload SAM CLI while working on your functions, changes will be reflected instantly/automatically. You only need to restart SAM CLI if you update your AWS SAM template
# 2022-03-11 06:15:21  * Running on http://127.0.0.1:3000/ (Press CTRL+C to quit)
# 2022-03-11 06:26:24 127.0.0.1 - - [11/Mar/2022 06:26:24] "GET /favicon.ico HTTP/1.1" 403 -

# %%
! settings

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="PASSWORD")

# %%
    1  ! pyenv shell 3.8.12
    2  ! sam init --runtime=python3.8
    3  ! pip install aws-sam-cli
    4  ! sam
    5  ! kdir samapp
    6  ! mkdir samapp
    7  ! cd samapp/
    8  ! python -m venv venv
    9  ! . ./venv/bin/activate
   10  ! sam init --runtime python3.7
   11  ! cd sam-app/
   12  ! sam build
   13  ! deactivate
   14  ! sam build
   15  ! sam
   16  ! sam build
   17  ! cd ..
   18  ! rm -rf ./sam-app/
   19  ! sam init --runtime python3.8
   20  ! cd ./sam-app/
   21  ! sam build
   22 !  sam local start-api
   23 !  sam deploy --guided
   24 !  aws
   25 !  aws configure
   26 !  sam deploy --guided
   27 !  ls -al
   28 !  history > build.txt
